# %%
import theano
import numpy as np
import time
import skimage.io

import sys
sys.path.insert(0, '/home/flipvanrijn/Workspace/Dedicon-Thesis/')

# %load_ext autoreload
# %autoreload 2
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# Using gpu device 0: Quadro K2200

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
np.set_printoptions(precision=5, suppress=True)

# Settings
EMBEDDING_SIZE = 512

# %%
# %%time
from networks.keras.vocab import Vocab

vocab = Vocab('/home/flipvanrijn/Workspace/Dedicon-Thesis/downloads/coco_train_dataset.json')
print 'Vocabulary loaded'
# Out:
# Reduced words from 25128 to 8853 with threshold 5
# Vocabulary loaded
# CPU times: user 22.7 s, sys: 1 s, total: 23.7 s
# Wall time: 23.7 s

# %%
from networks.keras.batchgenerator import BatchGenerator

bg = BatchGenerator(vocab)
Xs = bg.get_data(mode='binary', batch_size=5000)
Ys = bg.get_data(mode='index', batch_size=5000)

# %%
Xs = Xs.next()
Ys = Ys.next()

# %%
print Xs.shape
print Ys.shape
# Out:
# (5000, 30, 8856)
# (5000, 30)

# %%
# %%time
from keras.models import Sequential
from keras.layers.core import Dense, Activation, TimeDistributedDense
from keras.layers.recurrent import LSTM, Bidirectional
from keras.regularizers import l2

model = Sequential()
model.add(Bidirectional(LSTM, vocab.token_count, 512, return_sequences=True))
model.add(TimeDistributedDense(512, 30))
model.compile(loss='mse', optimizer='sgd', class_mode='categorical')

# %%
model.fit(Xs, Ys[:, np.newaxis, :], batch_size=128, show_accuracy=True)
# Out:
# Epoch 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-69909b69c82a> in <module>()
# ----> 1 model.fit(Xs, Ys[:, np.newaxis, :], batch_size=128, show_accuracy=True)
#
# /usr/local/lib/python2.7/site-packages/Keras-0.1.2-py2.7.egg/keras/models.pyc in fit(self, X, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, show_accuracy, class_weight, sample_weight)
#     463                          verbose=verbose, callbacks=callbacks,
#     464                          validation_split=validation_split, val_f=val_f, val_ins=val_ins,
# --> 465                          shuffle=shuffle, metrics=metrics)
#     466
#     467     def predict(self, X, batch_size=128, verbose=0):
#
# /usr/local/lib/python2.7/site-packages/Keras-0.1.2-py2.7.egg/keras/models.pyc in _fit(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, validation_split, val_f, val_ins, shuffle, metrics)
#     206                 batch_logs['size'] = len(batch_ids)
#     207                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 208                 outs = f(*ins_batch)
#     209                 if type(outs) != list:
#     210                     outs = [outs]
#
# /usr/local/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     604                         self.fn.nodes[self.fn.position_of_error],
#     605                         self.fn.thunks[self.fn.position_of_error],
# --> 606                         storage_map=self.fn.storage_map)
#     607                 else:
#     608                     # For the c linker We don't have access from
#
# /usr/local/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     593         t0_fn = time.time()
#     594         try:
# --> 595             outputs = self.fn()
#     596         except Exception:
#     597             if hasattr(self.fn, 'position_of_error'):
#
# ValueError: Input dimension mis-match. (input[0].shape[1] = 1, input[1].shape[1] = 30)
# Apply node that caused the error: Elemwise{sub,no_inplace}(AdvancedSubtensor.0, AdvancedSubtensor.0)
# Inputs types: [TensorType(float32, matrix), TensorType(float32, matrix)]
# Inputs shapes: [(128, 1), (128, 30)]
# Inputs strides: [(4, 4), (120, 4)]
# Inputs values: ['not shown', 'not shown']
#
# Backtrace when the node is created:
#   File "build/bdist.linux-x86_64/egg/keras/objectives.py", line 14, in mean_squared_error
#     return T.sqr(y_pred - y_true).mean(axis=-1)
#
# Debugprint of the apply node:
# Elemwise{sub,no_inplace} [@A] <TensorType(float32, matrix)> ''
#  |AdvancedSubtensor [@B] <TensorType(float32, matrix)> ''
#  | |HostFromGpu [@C] <TensorType(float32, 3D)> ''
#  | | |GpuElemwise{add,no_inplace} [@D] <CudaNdarrayType(float32, 3D)> ''
#  | |   |GpuDimShuffle{1,0,2} [@E] <CudaNdarrayType(float32, 3D)> ''
#  | |   | |GpuReshape{3} [@F] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   |GpuDot22 [@G] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | |GpuReshape{2} [@H] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | |GpuElemwise{add,no_inplace} [@I] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | |GpuSubtensor{int64:int64:int8} [@J] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | |forall_inplace,gpu,scan_fn}.0 [@K] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |Shape_i{0} [@M] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | |GpuReshape{3} [@N] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | |   |GpuDot22 [@O] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   | |GpuReshape{2} [@P] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   | | |GpuDimShuffle{1,0,2} [@Q] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | |   | | | |GpuFromHost [@R] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | |   | | |   |<TensorType(float32, 3D)> [@S] <TensorType(float32, 3D)>
#  | |   |   | | | | | | |   | | |MakeVector [@T] <TensorType(int64, vector)> ''
#  | |   |   | | | | | | |   | |   |Elemwise{mul,no_inplace} [@U] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | |   | |Shape_i{1} [@V] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | |   | | |<TensorType(float32, 3D)> [@S] <TensorType(float32, 3D)>
#  | |   |   | | | | | | |   | |   | |Shape_i{0} [@W] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | |   |   |<TensorType(float32, 3D)> [@S] <TensorType(float32, 3D)>
#  | |   |   | | | | | | |   | |   |Shape_i{2} [@X] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | |     |<TensorType(float32, 3D)> [@S] <TensorType(float32, 3D)>
#  | |   |   | | | | | | |   | |GpuReshape{2} [@Y] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   |   |GpuDimShuffle{0,1} [@Z] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   |   | |<CudaNdarrayType(float32, matrix)> [@BA] <CudaNdarrayType(float32, matrix)>
#  | |   |   | | | | | | |   |   |MakeVector [@BB] <TensorType(int64, vector)> ''
#  | |   |   | | | | | | |   |     |Shape_i{0} [@BC] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |     | |<CudaNdarrayType(float32, matrix)> [@BA] <CudaNdarrayType(float32, matrix)>
#  | |   |   | | | | | | |   |     |Shape_i{1} [@BD] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |       |<CudaNdarrayType(float32, matrix)> [@BA] <CudaNdarrayType(float32, matrix)>
#  | |   |   | | | | | | |   |MakeVector [@BE] <TensorType(int64, vector)> ''
#  | |   |   | | | | | | |     |Shape_i{1} [@V] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |     |Shape_i{0} [@W] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |     |Shape_i{1} [@BD] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |Shape_i{0} [@BF] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | |GpuReshape{3} [@BG] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | |   |GpuDot22 [@BH] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   | |GpuReshape{2} [@P] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   | |GpuReshape{2} [@BI] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   |   |GpuDimShuffle{0,1} [@BJ] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   |   | |<CudaNdarrayType(float32, matrix)> [@BK] <CudaNdarrayType(float32, matrix)>
#  | |   |   | | | | | | |   |   |MakeVector [@BL] <TensorType(int64, vector)> ''
#  | |   |   | | | | | | |   |     |Shape_i{0} [@BM] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |     | |<CudaNdarrayType(float32, matrix)> [@BK] <CudaNdarrayType(float32, matrix)>
#  | |   |   | | | | | | |   |     |Shape_i{1} [@BN] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |       |<CudaNdarrayType(float32, matrix)> [@BK] <CudaNdarrayType(float32, matrix)>
#  | |   |   | | | | | | |   |MakeVector [@BO] <TensorType(int64, vector)> ''
#  | |   |   | | | | | | |     |Shape_i{1} [@V] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |     |Shape_i{0} [@W] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |     |Shape_i{1} [@BN] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |Shape_i{0} [@BP] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | |GpuReshape{3} [@BQ] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | |   |GpuDot22 [@BR] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   | |GpuReshape{2} [@P] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   | |GpuReshape{2} [@BS] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   |   |GpuDimShuffle{0,1} [@BT] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   |   | |<CudaNdarrayType(float32, matrix)> [@BU] <CudaNdarrayType(float32, matrix)>
#  | |   |   | | | | | | |   |   |MakeVector [@BV] <TensorType(int64, vector)> ''
#  | |   |   | | | | | | |   |     |Shape_i{0} [@BW] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |     | |<CudaNdarrayType(float32, matrix)> [@BU] <CudaNdarrayType(float32, matrix)>
#  | |   |   | | | | | | |   |     |Shape_i{1} [@BX] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |       |<CudaNdarrayType(float32, matrix)> [@BU] <CudaNdarrayType(float32, matrix)>
#  | |   |   | | | | | | |   |MakeVector [@BY] <TensorType(int64, vector)> ''
#  | |   |   | | | | | | |     |Shape_i{1} [@V] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |     |Shape_i{0} [@W] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |     |Shape_i{1} [@BX] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |Shape_i{0} [@BZ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | |GpuReshape{3} [@CA] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | |   |GpuDot22 [@CB] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   | |GpuReshape{2} [@P] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   | |GpuReshape{2} [@CC] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   |   |GpuDimShuffle{0,1} [@CD] <CudaNdarrayType(float32, matrix)> ''
#  | |   |   | | | | | | |   |   | |<CudaNdarrayType(float32, matrix)> [@CE] <CudaNdarrayType(float32, matrix)>
#  | |   |   | | | | | | |   |   |MakeVector [@CF] <TensorType(int64, vector)> ''
#  | |   |   | | | | | | |   |     |Shape_i{0} [@CG] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |     | |<CudaNdarrayType(float32, matrix)> [@CE] <CudaNdarrayType(float32, matrix)>
#  | |   |   | | | | | | |   |     |Shape_i{1} [@CH] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |       |<CudaNdarrayType(float32, matrix)> [@CE] <CudaNdarrayType(float32, matrix)>
#  | |   |   | | | | | | |   |MakeVector [@CI] <TensorType(int64, vector)> ''
#  | |   |   | | | | | | |     |Shape_i{1} [@V] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |     |Shape_i{0} [@W] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |     |Shape_i{1} [@CH] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |Elemwise{add,no_inplace} [@CJ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | |   |TensorConstant{1} [@CK] <TensorType(int64, scalar)>
#  | |   |   | | | | | |   |Shape_i{1} [@V] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | |GpuSubtensor{int64:int64:int8} [@CL] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | |GpuElemwise{Add}[(0, 0)] [@CM] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | | |GpuReshape{3} [@N] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | | |GpuDimShuffle{x,x,0} [@CN] <CudaNdarrayType(float32, (True, True, False))> ''
#  | |   |   | | | | | | |   |<CudaNdarrayType(float32, vector)> [@CO] <CudaNdarrayType(float32, vector)>
#  | |   |   | | | | | | |ScalarFromTensor [@CP] <int64> ''
#  | |   |   | | | | | | | |Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}} [@CQ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Elemwise{le,no_inplace} [@CR] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   | |Elemwise{Composite{Switch(i0, Switch(LT((i1 + i2), i3), i3, (i1 + i2)), Switch(LT(i1, i2), i1, i2))}} [@CS] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |Elemwise{lt,no_inplace} [@CT] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   | | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |Shape_i{0} [@M] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |TensorConstant{0} [@CV] <TensorType(int64, scalar)>
#  | |   |   | | | | | | |   |Shape_i{0} [@M] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |ScalarFromTensor [@CW] <int64> ''
#  | |   |   | | | | | | | |Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}} [@CX] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Elemwise{le,no_inplace} [@CR] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |Elemwise{Composite{Switch(i0, Switch(LT((i1 + i2), i3), i3, (i1 + i2)), Switch(LT(i1, i2), i1, i2))}} [@CS] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Shape_i{0} [@M] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |Constant{1} [@CY] <int8>
#  | |   |   | | | | | |GpuSubtensor{int64:int64:int8} [@CZ] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | |GpuElemwise{Add}[(0, 0)] [@DA] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | | |GpuReshape{3} [@BG] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | | |GpuDimShuffle{x,x,0} [@DB] <CudaNdarrayType(float32, (True, True, False))> ''
#  | |   |   | | | | | | |   |<CudaNdarrayType(float32, vector)> [@DC] <CudaNdarrayType(float32, vector)>
#  | |   |   | | | | | | |ScalarFromTensor [@DD] <int64> ''
#  | |   |   | | | | | | | |Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}} [@DE] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Elemwise{le,no_inplace} [@DF] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   | |Elemwise{Composite{Switch(i0, Switch(LT((i1 + i2), i3), i3, (i1 + i2)), Switch(LT(i1, i2), i1, i2))}} [@DG] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |Elemwise{lt,no_inplace} [@CT] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |Shape_i{0} [@BF] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |TensorConstant{0} [@CV] <TensorType(int64, scalar)>
#  | |   |   | | | | | | |   |Shape_i{0} [@BF] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |ScalarFromTensor [@DH] <int64> ''
#  | |   |   | | | | | | | |Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}} [@DI] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Elemwise{le,no_inplace} [@DF] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |Elemwise{Composite{Switch(i0, Switch(LT((i1 + i2), i3), i3, (i1 + i2)), Switch(LT(i1, i2), i1, i2))}} [@DG] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Shape_i{0} [@BF] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |Constant{1} [@CY] <int8>
#  | |   |   | | | | | |GpuSubtensor{int64:int64:int8} [@DJ] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | |GpuElemwise{Add}[(0, 0)] [@DK] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | | |GpuReshape{3} [@BQ] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | | |GpuDimShuffle{x,x,0} [@DL] <CudaNdarrayType(float32, (True, True, False))> ''
#  | |   |   | | | | | | |   |<CudaNdarrayType(float32, vector)> [@DM] <CudaNdarrayType(float32, vector)>
#  | |   |   | | | | | | |ScalarFromTensor [@DN] <int64> ''
#  | |   |   | | | | | | | |Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}} [@DO] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Elemwise{le,no_inplace} [@DP] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   | |Elemwise{Composite{Switch(i0, Switch(LT((i1 + i2), i3), i3, (i1 + i2)), Switch(LT(i1, i2), i1, i2))}} [@DQ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |Elemwise{lt,no_inplace} [@CT] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |Shape_i{0} [@BP] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |TensorConstant{0} [@CV] <TensorType(int64, scalar)>
#  | |   |   | | | | | | |   |Shape_i{0} [@BP] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |ScalarFromTensor [@DR] <int64> ''
#  | |   |   | | | | | | | |Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}}[(0, 2)] [@DS] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Elemwise{le,no_inplace} [@DP] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |Elemwise{Composite{Switch(i0, Switch(LT((i1 + i2), i3), i3, (i1 + i2)), Switch(LT(i1, i2), i1, i2))}} [@DQ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Shape_i{0} [@BP] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |Constant{1} [@CY] <int8>
#  | |   |   | | | | | |GpuSubtensor{int64:int64:int8} [@DT] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | |GpuElemwise{Add}[(0, 0)] [@DU] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | | |GpuReshape{3} [@CA] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | | |GpuDimShuffle{x,x,0} [@DV] <CudaNdarrayType(float32, (True, True, False))> ''
#  | |   |   | | | | | | |   |<CudaNdarrayType(float32, vector)> [@DW] <CudaNdarrayType(float32, vector)>
#  | |   |   | | | | | | |ScalarFromTensor [@DX] <int64> ''
#  | |   |   | | | | | | | |Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}} [@DY] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Elemwise{le,no_inplace} [@DZ] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   | |Elemwise{Composite{Switch(i0, Switch(LT((i1 + i2), i3), i3, (i1 + i2)), Switch(LT(i1, i2), i1, i2))}} [@EA] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |Elemwise{lt,no_inplace} [@CT] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |Shape_i{0} [@BZ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |TensorConstant{0} [@CV] <TensorType(int64, scalar)>
#  | |   |   | | | | | | |   |Shape_i{0} [@BZ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |ScalarFromTensor [@EB] <int64> ''
#  | |   |   | | | | | | | |Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}} [@EC] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Elemwise{le,no_inplace} [@DZ] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |Elemwise{Composite{Switch(i0, Switch(LT((i1 + i2), i3), i3, (i1 + i2)), Switch(LT(i1, i2), i1, i2))}} [@EA] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Shape_i{0} [@BZ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |Constant{1} [@CY] <int8>
#  | |   |   | | | | | |Subtensor{int64:int64:int8} [@ED] <TensorType(int8, (False, False, True))> ''
#  | |   |   | | | | | | |Elemwise{Cast{int8}} [@EE] <TensorType(int8, (False, False, True))> ''
#  | |   |   | | | | | | | |Join [@EF] <TensorType(float32, (False, False, True))> ''
#  | |   |   | | | | | | |   |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |Alloc [@EG] <TensorType(float32, (True, False, True))> ''
#  | |   |   | | | | | | |   | |TensorConstant{0.0} [@EH] <TensorType(float32, scalar)>
#  | |   |   | | | | | | |   | |TensorConstant{1} [@EI] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   | |Shape_i{0} [@W] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | |TensorConstant{1} [@EI] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |InplaceDimShuffle{1,0,x} [@EJ] <TensorType(float32, (False, False, True))> ''
#  | |   |   | | | | | | |     |Alloc [@EK] <TensorType(float32, matrix)> ''
#  | |   |   | | | | | | |       |TensorConstant{(1, 1) of 1.0} [@EL] <TensorType(float32, (True, True))>
#  | |   |   | | | | | | |       |Shape_i{0} [@W] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |       |Shape_i{1} [@V] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |ScalarFromTensor [@EM] <int64> ''
#  | |   |   | | | | | | | |Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}} [@EN] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Elemwise{le,no_inplace} [@EO] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   | |Elemwise{Composite{Switch(i0, Switch(LT((i1 + i2 + i3), i4), i4, (i1 + i2 + i3)), Switch(LT(i2, i5), i2, i5))}} [@EP] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |Elemwise{lt,no_inplace} [@CT] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   | | |TensorConstant{1} [@CK] <TensorType(int64, scalar)>
#  | |   |   | | | | | | |   | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |Shape_i{1} [@V] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   | | |Elemwise{add,no_inplace} [@CJ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |TensorConstant{0} [@CV] <TensorType(int64, scalar)>
#  | |   |   | | | | | | |   |Elemwise{add,no_inplace} [@CJ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |ScalarFromTensor [@EQ] <int64> ''
#  | |   |   | | | | | | | |Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}} [@ER] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Elemwise{le,no_inplace} [@EO] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | |   |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |   |Elemwise{Composite{Switch(i0, Switch(LT((i1 + i2 + i3), i4), i4, (i1 + i2 + i3)), Switch(LT(i2, i5), i2, i5))}} [@EP] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |   |Elemwise{add,no_inplace} [@CJ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |Constant{1} [@CY] <int8>
#  | |   |   | | | | | |GpuAlloc{memset_0=True} [@ES] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | |CudaNdarrayConstant{0.0} [@ET] <CudaNdarrayType(float32, scalar)>
#  | |   |   | | | | | | |Elemwise{sub,no_inplace} [@EU] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | |Elemwise{Composite{Switch(LT(maximum(i0, i1), i2), Switch(LT((maximum(i0, i1) + i1 + i3), i2), i2, (maximum(i0, i1) + i1 + i3)), Switch(LT(maximum(i0, i1), i4), maximum(i0, i1), i4))}} [@EV] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | |Elemwise{Composite{maximum(maximum(((i0 - Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Composite{Switch(i0, (i1 - i2), i3)}(i1, i2, i3, i4) + i3), Composite{((((i0 - i1) - i2) // i2) + i2)}(Composite{Switch(i0, (i1 - i2), i3)}(i1, i2, i3, i4), i5, i3), i6, i3), i6, (Composite{Switch(i0, (i1 - i2), i3)}(i1, i2, i3, i4) + i3), i3), i6), Composite{Switch(LT(i0, i1), i1, i0)}((Composite{Switch(i0, (i1 - i2), i3)}(i1, i2, i3, i4) + i3), i6)), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Composite{Switch(i0, (i1 - i2), i3)}(i1, i2, i3, i4) + i3), Composite{((((i0 - i1) - i2) // i2) + i2)}(Composite{Switch(i0, (i1 - i2), i3)}(i1, i2, i3, i4), i5, i3), i6, i3), i6, (Composite{Switch(i0, (i1 - i2), i3)}(i1, i2, i3, i4) + i3), i3), i6), Composite{Switch(LT(i0, i1), i1, i0)}((Composite{Switch(i0, (i1 - i2), i3)}(i1, i2, i3, i4) + i3), i6))) + i3), i3), maximum(((i0 - i7) + i3), i3))}} [@EW] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | |Elemwise{ge,no_inplace} [@EX] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | | | | | |Elemwise{Composite{Switch(LT(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4), i5, Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3))}} [@EY] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | |Elemwise{lt,no_inplace} [@EZ] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | | | | | | | |Elemwise{Composite{Switch(i0, i1, maximum(minimum((i2 + i3), i4), i5))}}[(0, 3)] [@FA] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | |Elemwise{le,no_inplace} [@FB] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | |Elemwise{sub,no_inplace} [@FC] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | |Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}} [@FD] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |Elemwise{add,no_inplace} [@FE] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | | |TensorConstant{1} [@CK] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | | | | | | | | | |Elemwise{Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4), i6, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5))}}[(0, 6)] [@FF] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   |Elemwise{le,no_inplace} [@FG] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | |Elemwise{Composite{Switch(i0, Switch(LT(Composite{((i0 + i1) - i2)}(i1, i2, i3), i4), i4, Composite{((i0 + i1) - i2)}(i1, i2, i3)), Switch(LT(i1, (i2 - i3)), i1, (i2 - i3)))}}[(0, 2)] [@FH] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | | |Elemwise{lt,no_inplace} [@CT] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | | |Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}} [@FI] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | | | |Elemwise{switch,no_inplace} [@FJ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | | | | |Elemwise{lt,no_inplace} [@CT] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | | | | | |   | | | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | | | | | |   | | |Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}} [@FK] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | | | |Elemwise{switch,no_inplace} [@FJ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | | | |TensorConstant{1} [@CK] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | | | | | | | | |   | | | |Elemwise{add,no_inplace} [@FL] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | | | | |TensorConstant{-1} [@FM] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | | | | | | | | |   | | | | |Elemwise{switch,no_inplace} [@FJ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | | | | | |   | | | |Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}} [@FI] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | | | | | |   | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | | | | | |   |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | | | | | |   |Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}} [@FK] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   |Elemwise{add,no_inplace} [@FN] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   | |TensorConstant{-1} [@FM] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | | | | | | | | |   | |Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}} [@FI] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   |Elemwise{switch,no_inplace} [@FJ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |   |TensorConstant{-1} [@FO] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | | | | | |   |Elemwise{add,no_inplace} [@FL] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | | | | |Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11)}}[(0, 0)] [@FP] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | |   |Elemwise{add,no_inplace} [@FE] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | |   |TensorConstant{1} [@CK] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | | | | | | |   |TensorConstant{-1} [@FM] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | | | | | | |   |Elemwise{Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4), i6, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, maximum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5))}}[(0, 6)] [@FF] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | |   |Elemwise{le,no_inplace} [@FG] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | |   |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | | | |   |Elemwise{add,no_inplace} [@FN] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | |   |Elemwise{Composite{Switch(i0, Switch(LT(Composite{((i0 + i1) - i2)}(i1, i2, i3), i4), i4, Composite{((i0 + i1) - i2)}(i1, i2, i3)), Switch(LT(i1, (i2 - i3)), i1, (i2 - i3)))}}[(0, 2)] [@FH] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | |   |Elemwise{switch,no_inplace} [@FJ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | |   |Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}} [@FK] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | |   |TensorConstant{-1} [@FO] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | | | |   |Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}} [@FD] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | | |TensorConstant{-1} [@FM] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | | | | | |Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}} [@FD] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | |Elemwise{switch,no_inplace} [@FJ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | |TensorConstant{0} [@CV] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | |Elemwise{Composite{Switch(i0, i1, maximum(minimum((i2 + i3), i4), i5))}}[(0, 3)] [@FA] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | |TensorConstant{1} [@CK] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | |TensorConstant{-1} [@FO] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | |Elemwise{add,no_inplace} [@FQ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | |   |TensorConstant{1} [@CK] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | |   |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | |Elemwise{add,no_inplace} [@FQ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | |TensorConstant{1} [@CK] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | |Elemwise{Composite{Switch(LT(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4), i5, Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3))}} [@EY] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | |Elemwise{Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i6, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}}[(0, 1)] [@FR] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | |Elemwise{lt,no_inplace} [@FS] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | | | | | | |Elemwise{Composite{Switch(i0, i1, Switch(AND(LT((i2 + i3), i1), GT(i4, i1)), i5, minimum((i2 + i3), i6)))}}[(0, 3)] [@FT] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | |Elemwise{le,no_inplace} [@FB] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | | | | | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | |TensorConstant{-1} [@FM] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | | | | |Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11)}}[(0, 0)] [@FP] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | |Elemwise{sub,no_inplace} [@FC] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | |Elemwise{sub,no_inplace} [@FU] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | |TensorConstant{-2} [@FV] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | | | | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | |Elemwise{switch,no_inplace} [@FJ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | |Elemwise{Composite{Switch(i0, i1, Switch(AND(LT((i2 + i3), i1), GT(i4, i1)), i5, minimum((i2 + i3), i6)))}}[(0, 3)] [@FT] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | |TensorConstant{1} [@CK] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | |TensorConstant{-1} [@FO] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | |Elemwise{add,no_inplace} [@FQ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | |Elemwise{Composite{Switch(LT(i0, i1), i0, i1)}} [@FW] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | |   |TensorConstant{1} [@CK] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | |   |Elemwise{add,no_inplace} [@FQ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | |TensorConstant{1} [@CK] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | |Elemwise{add,no_inplace} [@FQ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | |Shape_i{0} [@W] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | |TensorConstant{512} [@FX] <TensorType(int64, scalar)>
#  | |   |   | | | | | |GpuAlloc{memset_0=True} [@FY] <CudaNdarrayType(float32, 3D)> ''
#  | |   |   | | | | | | |CudaNdarrayConstant{0.0} [@ET] <CudaNdarrayType(float32, scalar)>
#  | |   |   | | | | | | |Elemwise{sub,no_inplace} [@FZ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | |Elemwise{Composite{Switch(LT(maximum(i0, i1), i2), Switch(LT((maximum(i0, i1) + i1 + i3), i2), i2, (maximum(i0, i1) + i1 + i3)), Switch(LT(maximum(i0, i1), i4), maximum(i0, i1), i4))}} [@GA] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | |Elemwise{Composite{maximum(maximum(((i0 - Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), Composite{((((i0 - Switch(GE(i1, i2), i2, i1)) - i3) // i3) + i3)}(Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)), Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i6, i7, i0, i3), i4, i5), (i0 + i3), i3), i4, i3), i4, (Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), i4)), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), Composite{((((i0 - Switch(GE(i1, i2), i2, i1)) - i3) // i3) + i3)}(Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)), Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i6, i7, i0, i3), i4, i5), (i0 + i3), i3), i4, i3), i4, (Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), i4))) + i3), i3), maximum(((i0 - Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i8, i9, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), Composite{((((i0 - Switch(GE(i1, i2), i2, i1)) - i3) // i3) + i3)}(Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i ...
#  | |   |   | | | | | | | | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | |Elemwise{lt,no_inplace} [@GC] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | | | | | |Elemwise{Composite{Switch(i0, i1, maximum(i2, (i3 - i4)))}} [@GD] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | |Elemwise{le,no_inplace} [@GE] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | | | | | | | |Elemwise{sub,no_inplace} [@GF] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | |Elemwise{Composite{Switch(LT(Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, minimum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4), i1), i1, Composite{Switch(GE(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, minimum(i2, i3))}(i0, i1, i2, i3), i1, i4), i1, i5), i4))}} [@GG] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | |Elemwise{le,no_inplace} [@GH] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | |Elemwise{Composite{Switch(i0, Switch(LT((i1 + i2), i3), i3, (i1 + i2)), Switch(LT(i1, i2), i1, i2))}} [@GI] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |Elemwise{lt,no_inplace} [@CT] <TensorType(int8, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |Elemwise{Composite{minimum(minimum(minimum(minimum(i0, i1), i2), i3), i4)}} [@L] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | |Elemwise{Composite{Switch(LT((i0 + i1), i2), i2, (i0 + i1))}} [@GJ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | | |TensorConstant{-1} [@FM] <TensorType(int64, scalar)>
#  | |   |   | | | | | | | | | | | | | | | | | |Elemwise{sub,no_inplace} [@GK] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | | | |Elemwise{Composite{Switch(LT(i0, i1), i1, i0)}} [@GL] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | | | | |Elemwise{add,no_inplace} [@FQ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | | | | |TensorConstant{0} [@CU] <TensorType(int8, scalar)>
#  | |   |   | | | | | | | | | | | | | | | | | | |Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (i1 // i0))}(i1, i2), i3), i3, i2), i3), i4)}} [@GM] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | | |   |Elemwise{add,no_inplace} [@FQ] <TensorType(int64, scalar)> ''
#  | |   |   | | | | | | | | | | | | | | | | | |   |TensorConstant{1} [@CK] <TensorType(int64, scalar)>
# ...
#  - <CudaNdarrayType(float32, matrix)>, Shape: (512, 512), ElemSize: 4 Byte(s), TotalSize: 1048576 Byte(s)
#  - GpuReshape{2}.0, Shape: (8856, 512), ElemSize: 4 Byte(s), TotalSize: 18137088 Byte(s)
#  - GpuElemwise{Add}[(0, 0)].0, Shape: (30, 128, 512), ElemSize: 4 Byte(s), TotalSize: 7864320 Byte(s)
#  - GpuElemwise{Add}[(0, 0)].0, Shape: (30, 128, 512), ElemSize: 4 Byte(s), TotalSize: 7864320 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (8856, 512), ElemSize: 4 Byte(s), TotalSize: 18137088 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (512, 512), ElemSize: 4 Byte(s), TotalSize: 1048576 Byte(s)
#  - Shape_i{0}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (512, 512), ElemSize: 4 Byte(s), TotalSize: 1048576 Byte(s)
#  - GpuElemwise{Add}[(0, 0)].0, Shape: (30, 128, 512), ElemSize: 4 Byte(s), TotalSize: 7864320 Byte(s)
#  - TensorConstant{(1, 1) of 1.0}, Shape: (1, 1), ElemSize: 4 Byte(s), TotalSize: 4 Byte(s)
#  - <CudaNdarrayType(float32, vector)>, Shape: (512,), ElemSize: 4 Byte(s), TotalSize: 2048 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (512, 1), ElemSize: 4 Byte(s), TotalSize: 2048 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, maximum(i2, i3))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - <CudaNdarrayType(float32, vector)>, Shape: (512,), ElemSize: 4 Byte(s), TotalSize: 2048 Byte(s)
#  - Shape_i{2}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (512, 512), ElemSize: 4 Byte(s), TotalSize: 1048576 Byte(s)
#  - <CudaNdarrayType(float32, vector)>, Shape: (512,), ElemSize: 4 Byte(s), TotalSize: 2048 Byte(s)
#  - Elemwise{lt,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - Shape_i{2}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (8856, 512), ElemSize: 4 Byte(s), TotalSize: 18137088 Byte(s)
#  - Elemwise{ge,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - TensorConstant{1}, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - <TensorType(float32, 3D)>, Shape: (128, 30, 8856), ElemSize: 4 Byte(s), TotalSize: 136028160 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (512, 512), ElemSize: 4 Byte(s), TotalSize: 1048576 Byte(s)
#  - <CudaNdarrayType(float32, vector)>, Shape: (512,), ElemSize: 4 Byte(s), TotalSize: 2048 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (8856, 512), ElemSize: 4 Byte(s), TotalSize: 18137088 Byte(s)
#  - <CudaNdarrayType(float32, vector)>, Shape: (512,), ElemSize: 4 Byte(s), TotalSize: 2048 Byte(s)
#  - y, Shape: (128, 1, 30), ElemSize: 4 Byte(s), TotalSize: 15360 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (512, 512), ElemSize: 4 Byte(s), TotalSize: 1048576 Byte(s)
#  - forall_inplace,gpu,scan_fn}.1, Shape: (31, 128, 512), ElemSize: 4 Byte(s), TotalSize: 8126464 Byte(s)
#  - <CudaNdarrayType(float32, vector)>, Shape: (512,), ElemSize: 4 Byte(s), TotalSize: 2048 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (8856, 512), ElemSize: 4 Byte(s), TotalSize: 18137088 Byte(s)
#  - Shape_i{2}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (512, 512), ElemSize: 4 Byte(s), TotalSize: 1048576 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (512, 512), ElemSize: 4 Byte(s), TotalSize: 1048576 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (8856, 512), ElemSize: 4 Byte(s), TotalSize: 18137088 Byte(s)
#  - Elemwise{lt,no_inplace}.0, Shape: (1,), ElemSize: 1 Byte(s), TotalSize: 1.0 Byte(s)
#  - GpuReshape{3}.0, Shape: (30, 128, 1), ElemSize: 4 Byte(s), TotalSize: 15360 Byte(s)
#  - Shape_i{2}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (8856, 512), ElemSize: 4 Byte(s), TotalSize: 18137088 Byte(s)
#  - Elemwise{Composite{Switch(i0, i1, minimum(i2, i3))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{maximum(maximum(((i0 - Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), Composite{((((i0 - Switch(GE(i1, i2), i2, i1)) - i3) // i3) + i3)}(Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)), Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i6, i7, i0, i3), i4, i5), (i0 + i3), i3), i4, i3), i4, (Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), i4)), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), Composite{((((i0 - Switch(GE(i1, i2), i2, i1)) - i3) // i3) + i3)}(Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)), Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i6, i7, i0, i3), i4, i5), (i0 + i3), i3), i4, i3), i4, (Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), i4))) + i3), i3), maximum(((i0 - Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i8, i9, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), Composite{((((i0 - Switch(GE(i1, i2), i2, i1)) - i3) // i3) + i3)}(Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch( ...
#  - Elemwise{Composite{Switch(i0, Switch(LT((i1 + i2 + i3), i4), i4, (i1 + i2 + i3)), Switch(LT(i2, i5), i2, i5))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (8856, 512), ElemSize: 4 Byte(s), TotalSize: 18137088 Byte(s)
#  - Shape_i{0}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - <CudaNdarrayType(float32, scalar)>, Shape: (1,), ElemSize: 4 Byte(s), TotalSize: 4.0 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (512, 512), ElemSize: 4 Byte(s), TotalSize: 1048576 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (8856, 512), ElemSize: 4 Byte(s), TotalSize: 18137088 Byte(s)
#  - <CudaNdarrayType(float32, matrix)>, Shape: (8856, 512), ElemSize: 4 Byte(s), TotalSize: 18137088 Byte(s)
#  - <CudaNdarrayType(float32, vector)>, Shape: (512,), ElemSize: 4 Byte(s), TotalSize: 2048 Byte(s)
#  - Shape_i{1}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuReshape{2}.0, Shape: (8856, 512), ElemSize: 4 Byte(s), TotalSize: 18137088 Byte(s)
#  - Elemwise{add,no_inplace}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{maximum(maximum(((i0 - Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), Composite{((((i0 - Switch(GE(i1, i2), i2, i1)) - i3) // i3) + i3)}(Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)), Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i6, i7, i0, i3), i4, i5), (i0 + i3), i3), i4, i3), i4, (Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), i4)), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), Composite{((((i0 - Switch(GE(i1, i2), i2, i1)) - i3) // i3) + i3)}(Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)), Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i6, i7, i0, i3), i4, i5), (i0 + i3), i3), i4, i3), i4, (Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), i3), i4), Composite{Switch(LT(i0, i1), i1, i0)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i1, i2, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), i4))) + i3), i3), maximum(((i0 - Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), (i2 - i3), i0)}(Composite{((i0 - (Switch(LT(i1, i2), i2, i1) - i3)) - i3)}((Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5))}(i8, i9, i0, i3, i4, i5, (i0 + i3), ((i0 + i3) - i3)) + i3), Composite{((((i0 - Switch(GE(i1, i2), i2, i1)) - i3) // i3) + i3)}(Composite{Switch(GE(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(i0, (i1 + i2 + i3), i1)}(i0, i1, i2, i3), i4, i5), i6), i7, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch( ...
#  - Shape_i{0}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Shape_i{1}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(i0, Switch(LT((i1 + i2), i3), i3, (i1 + i2)), Switch(LT(i1, i2), i1, i2))}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - <CudaNdarrayType(float32, vector)>, Shape: (512,), ElemSize: 4 Byte(s), TotalSize: 2048 Byte(s)
#  - Shape_i{1}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - Elemwise{Composite{Switch(LT(Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11), Composite{Switch(LT(i0, i1), i1, i0)}(Composite{Switch(LT(i0, i1), i2, i0)}(Composite{(i0 - Switch(LT(i1, i2), i2, i1))}(i0, Composite{(i0 + (((i1 + i2) - Switch(GE(i3, i4), i4, i3)) // i0))}(i1, i2, i3, Composite{Switch(LT(i0, i1), i2, i0)}(Composite{Switch(LT(i0, i1), (i0 + i2), i0)}(Composite{Switch(i0, i1, Switch(AND(LT(i2, i1), GT(i3, i1)), (i4 - i5), maximum((i4 + i6), i2)))}(i4, i5, (i6 - i7), i7, i2, i8, i9), i5, i8), i5, i10), i8), i5), i5, i3), i5), i11)}}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
#  - GpuReshape{2}.0, Shape: (8856, 512), ElemSize: 4 Byte(s), TotalSize: 18137088 Byte(s)
#  - GpuReshape{2}.0, Shape: (8856, 512), ElemSize: 4 Byte(s), TotalSize: 18137088 Byte(s)
#  - Shape_i{1}.0, Shape: (1,), ElemSize: 8 Byte(s), TotalSize: 8.0 Byte(s)
